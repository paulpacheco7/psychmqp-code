# %% [markdown]
# # Demographic Survey Data #
#
# ----Load in Demographic Survey Data---
#
# Import pandas as pd

# %%
import pandas as pd

# %% [markdown]
# Import Data File

# %%
df = pd.read_csv('/Users/paulpacheco/Desktop/Test Data Files/demographicsurvey_survey_demographics_2203041344.csv')
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_column', 100)
df
# Out:
#          date      time  group    subject  session  build  \
# 0  2022-01-27  13:14:00      2   23140554        1  6.5.2
# 1  2022-01-27  14:14:46      1  664692613        1  6.5.2
# 2  2022-02-02  14:21:30      2  599191245        1  6.5.2
# 3  2022-02-03  13:21:34      2  481626968        1  6.5.2
# 4  2022-02-08  14:18:07      2  299228195        1  6.5.2
# 5  2022-02-15  14:36:47      1  464449427        1  6.5.2
# 6  2022-02-18  16:29:41      1  828122693        1  6.5.2
# 7  2022-02-22  12:29:56      2  835352491        1  6.5.2
# 8  2022-02-24  13:54:53      1  956226984        1  6.5.2
# 9  2022-03-02  13:46:25      1  325562366        1  6.5.2
#
#                  gender_response  gender_latency  genderother_response  \
# 0                         Female            4632                   NaN
# 1                         Female            7921                   NaN
# 2  Gender Variant/Non-Conforming            5472                   NaN
# ...

# %% [markdown]
# Filter colomns by the headers you would like

# %%
df=df[['subject','group','gender_response','genderother_response','age_response','ethnicity_response','raceoriginoption1_response','raceoriginoption2_response','raceoriginoption3_response','raceoriginoption4_response','raceoriginoption5_response','raceoriginoption6_response','raceoriginoption7_response','raceoriginoption8_response','raceoriginoption9_response','raceoriginoption10_response','raceoriginoption11_response','raceoriginoption12_response','raceoriginoption13_response','raceoriginother_response','highest_level_of_education_response','highest_level_of_educationother_response','year_in_College_response','major_response','household_education_response','homeownership_response','rooms_in_house_response','region_of_us_response','region_of_usother_response']]
df
# Out:
#      subject  group                gender_response  genderother_response  \
# 0   23140554      2                         Female                   NaN
# 1  664692613      1                         Female                   NaN
# 2  599191245      2  Gender Variant/Non-Conforming                   NaN
# 3  481626968      2                           Male                   NaN
# 4  299228195      2                         Female                   NaN
# 5  464449427      1                         Female                   NaN
# 6  828122693      1                           Male                   NaN
# 7  835352491      2                           Male                   NaN
# 8  956226984      1                         Female                   NaN
# 9  325562366      1                           Male                   NaN
#
#    age_response                                 ethnicity_response  \
# 0            21  Hispanic or Latino (a person of Cuban, Mexican...
# ...

# %% [markdown]
# This data has been sorted and is ready to be merged in SPSS
